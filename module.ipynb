# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset from the Local Host

# %%
df = pd.read_csv("C:/Users/mayam/Downloads/data.csv")

# %%
df
# Out:
#          Date      Open      High       Low     Close  Shares Traded  \
# 0    1-Apr-20   8584.10   8588.10   8198.35   8253.80      507509685
# 1    3-Apr-20   8356.55   8356.55   8055.80   8083.80      697752438
# 2    7-Apr-20   8446.30   8819.40   8360.95   8792.20      815245226
# 3    8-Apr-20   8688.90   9131.70   8653.90   8748.75      897562690
# 4    9-Apr-20   8973.05   9128.35   8904.55   9111.90      743036134
# ..        ...       ...       ...       ...       ...            ...
# 73  21-Jul-20  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-Jul-20  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-Jul-20  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-Jul-20  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-Jul-20  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover (Rs. Cr)
# 0            21307.30
# 1            26561.18
# 2            35206.69
# 3            37641.68
# ...

# %%
df['Date']
# Out:
# 0      1-Apr-20
# 1      3-Apr-20
# 2      7-Apr-20
# 3      8-Apr-20
# 4      9-Apr-20
#         ...
# 73    21-Jul-20
# 74    22-Jul-20
# 75    23-Jul-20
# 76    24-Jul-20
# 77    27-Jul-20
# Name: Date, Length: 78, dtype: object

# %%
df["Date"][0]="01-04-2020"
df["Date"][1]="02-04-2020"
df["Date"][2]="03-04-2020"
df["Date"][3]="07-04-2020"
df["Date"][4]="08-04-2020"
df["Date"][5]="09-04-2020"
df["Date"][6]="13-04-2020"
df["Date"][7]="15-04-2020"
df["Date"][8]="16-04-2020"
df["Date"][9]="17-04-2020"
df["Date"][10]="20-04-2020"
df["Date"][11]="21-04-2020"
df["Date"][12]="22-04-2020"
df["Date"][13]="23-04-2020"
df["Date"][14]="24-04-2020"
df["Date"][15]="27-04-2020"
df["Date"][16]="28-04-2020"
df["Date"][17]="29-04-2020"
df["Date"][18]="04-05-2020"
df["Date"][19]="05-05-2020"
df["Date"][20]="06-05-2020"
df["Date"][21]="07-05-2020"
df["Date"][22]="08-05-2020"
df["Date"][23]="11-05-2020"
df["Date"][24]="12-05-2020"
df["Date"][25]="13-05-2020"
df["Date"][26]="14-05-2020"
df["Date"][27]="15-05-2020"
df["Date"][28]="18-05-2020"
df["Date"][29]="19-05-2020"
df["Date"][30]="20-05-2020"
df["Date"][31]="21-05-2020"
df["Date"][32]="22-05-2020"
df["Date"][33]="26-05-2020"
df["Date"][34]="27-05-2020"
df["Date"][35]="28-05-2020"
df["Date"][36]="29-05-2020"
df["Date"][37]="01-06-2020"
df["Date"][38]="02-06-2020"
df["Date"][39]="03-06-2020"
df["Date"][40]="04-06-2020"
df["Date"][41]="05-06-2020"
df["Date"][42]="08-06-2020"
df["Date"][43]="09-06-2020"
df["Date"][44]="10-06-2020"
df["Date"][45]="11-06-2020"
df["Date"][46]="12-06-2020"
df["Date"][47]="15-06-2020"
df["Date"][48]="16-06-2020"
df["Date"][49]="17-06-2020"
df["Date"][50]="18-06-2020"
df["Date"][51]="19-06-2020"
df["Date"][52]="22-06-2020"
df["Date"][53]="23-06-2020"
df["Date"][54]="24-06-2020"
df["Date"][55]="25-06-2020"
df["Date"][56]="26-06-2020"
df["Date"][57]="29-06-2020"
df["Date"][58]="30-07-2020"
df["Date"][59]="01-07-2020"
df["Date"][60]="02-07-2020"
df["Date"][61]="03-07-2020"
df["Date"][62]="06-07-2020"
df["Date"][63]="07-07-2020"
df["Date"][64]="08-07-2020"
df["Date"][65]="09-07-2020"
df["Date"][66]="10-07-2020"
df["Date"][67]="13-07-2020"
df["Date"][68]="14-07-2020"
df["Date"][69]="15-07-2020"
df["Date"][70]="16-07-2020"
df["Date"][71]="17-07-2020"
df["Date"][72]="20-07-2020"
df["Date"][73]="21-07-2020"
df["Date"][74]="22-07-2020"
df["Date"][75]="23-07-2020"
df["Date"][76]="24-07-2020"
df["Date"][77]="27-07-2020"
# Out:
# C:\Users\mayam\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mayam\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mayam\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Shares Traded  \
# 0  01-04-2020  8584.10  8588.10  8198.35  8253.80      507509685
# 1  02-04-2020  8356.55  8356.55  8055.80  8083.80      697752438
# 2  03-04-2020  8446.30  8819.40  8360.95  8792.20      815245226
# 3  07-04-2020  8688.90  9131.70  8653.90  8748.75      897562690
# 4  08-04-2020  8973.05  9128.35  8904.55  9111.90      743036134
#
#    Turnover (Rs. Cr)
# 0           21307.30
# 1           26561.18
# 2           35206.69
# 3           37641.68
# 4           32907.82

# %%
df.tail()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 73  21-07-2020  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-07-2020  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-07-2020  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-07-2020  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-07-2020  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover (Rs. Cr)
# 73           42461.89
# 74           41068.72
# 75           32744.93
# 76           40217.17
# 77           34539.73

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Shares Traded  \
# count     78.000000     78.000000     78.000000     78.000000   7.800000e+01
# mean    9832.007692   9922.894872   9726.659615   9824.650641   7.081254e+08
# std      752.246361    731.135825    774.830381    764.009692   1.155232e+08
# min     8356.550000   8356.550000   8055.800000   8083.800000   5.075097e+08
# 25%     9200.787500   9285.050000   9097.637500   9197.175000   6.224551e+08
# 50%     9808.375000   9969.475000   9727.425000   9870.525000   6.909449e+08
# 75%    10381.675000  10475.287500  10301.212500  10418.287500   7.715473e+08
# max    11231.200000  11239.800000  11113.250000  11215.450000   9.941909e+08
#
#        Turnover (Rs. Cr)
# count          78.000000
# mean        33883.435897
# std          5847.849306
# min         21307.300000
# 25%         30354.487500
# 50%         32741.785000
# 75%         37412.037500
# max         59705.530000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Shares Traded',
#        'Turnover (Rs. Cr)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                  object
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Shares Traded          int64
# Turnover (Rs. Cr)    float64
# dtype: object

# %%
df.tail()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 73  21-07-2020  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-07-2020  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-07-2020  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-07-2020  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-07-2020  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover (Rs. Cr)
# 73           42461.89
# 74           41068.72
# 75           32744.93
# 76           40217.17
# 77           34539.73

# %% [markdown]
# # Finding Missing Values

# %%
#we dont have any missing values over here!

# %%
df.isnull().any()
# Out:
# Date                 False
# Open                 False
# High                 False
# Low                  False
# Close                False
# Shares Traded        False
# Turnover (Rs. Cr)    False
# dtype: bool

# %%
# we have 78 observations over here

# %%
df.shape
# Out:
# (78, 7)

# %% [markdown]
# # Changing the column name

# %%
df.rename(columns={"Turnover (Rs. Cr)":"Turnover in Cr"},inplace = True )

# %%
df
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0   01-04-2020   8584.10   8588.10   8198.35   8253.80      507509685
# 1   02-04-2020   8356.55   8356.55   8055.80   8083.80      697752438
# 2   03-04-2020   8446.30   8819.40   8360.95   8792.20      815245226
# 3   07-04-2020   8688.90   9131.70   8653.90   8748.75      897562690
# 4   08-04-2020   8973.05   9128.35   8904.55   9111.90      743036134
# ..         ...       ...       ...       ...       ...            ...
# 73  21-07-2020  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-07-2020  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-07-2020  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-07-2020  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-07-2020  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover in Cr
# 0         21307.30
# 1         26561.18
# 2         35206.69
# 3         37641.68
# 4         32907.82
# ...

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(df['Turnover in Cr']);

# %%
df["Turnover in Cr"].plot.box(figsize=(10,5))

# %%
sns.distplot(df['Open']);

# %%
df["Open"].plot.box(figsize=(10,5))

# %%
sns.distplot(df['Close']);

# %%
df["Close"].plot.box()

# %%
sns.distplot(df['High']);

# %%
df["High"].plot.box()

# %%
sns.distplot(df['Low']);

# %%
df["Low"].plot.box()

# %%
sns.distplot(df['Shares Traded']);

# %%
df["Shares Traded"].plot.box()

# %%
#Let us draw a Stock Market Graph and let us see a difference

# %%
sns.set()
sns.set_style('whitegrid')
df["Open"].plot(figsize=(12,6),label="Open")
plt.title("Stock Open Price")
plt.legend()

# %%
sns.set()
sns.set_style('whitegrid')
df["Close"].plot(figsize=(12,6),label="close")
plt.title("Stock Close Price")
plt.legend()

# %%
sns.set()
sns.set_style('whitegrid')
df["Turnover in Cr"].plot(figsize=(12,6),label="Turnover in Cr")
plt.title("Stocl Turnover in Cr")
plt.legend()

# %%
sns.set()
sns.set_style('whitegrid')
df["High"].plot(figsize=(12,6),label="High")
plt.title("Stock High Price")
plt.legend()

# %%
sns.set()
sns.set_style('whitegrid')
df["Low"].plot(figsize=(12,6),label="Low")
plt.title("Stock Low Price")
plt.legend()

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(df.corr(),annot=True, linewidth=.5,)

# %%
matrix = df.corr() 
plt.subplots(figsize=(9, 6))
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %% [markdown]
# # Adding feature to Improve the Model

# %%
df['ohlc_average'] = (df['Open'] + df['High'] + df['Low'] + df['Close']) / 4

# %%
df['ohlc_average']
# Out:
# 0      8406.0875
# 1      8213.1750
# 2      8604.7125
# 3      8805.8125
# 4      9029.4625
#          ...
# 73    11145.2875
# 74    11164.6125
# 75    11173.3500
# 76    11164.9500
# 77    11167.4125
# Name: ohlc_average, Length: 78, dtype: float64

# %%
df
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0   01-04-2020   8584.10   8588.10   8198.35   8253.80      507509685
# 1   02-04-2020   8356.55   8356.55   8055.80   8083.80      697752438
# 2   03-04-2020   8446.30   8819.40   8360.95   8792.20      815245226
# 3   07-04-2020   8688.90   9131.70   8653.90   8748.75      897562690
# 4   08-04-2020   8973.05   9128.35   8904.55   9111.90      743036134
# ..         ...       ...       ...       ...       ...            ...
# 73  21-07-2020  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-07-2020  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-07-2020  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-07-2020  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-07-2020  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover in Cr  ohlc_average
# 0         21307.30     8406.0875
# 1         26561.18     8213.1750
# ...

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Shares Traded  \
# 0  01-04-2020  8584.10  8588.10  8198.35  8253.80      507509685
# 1  02-04-2020  8356.55  8356.55  8055.80  8083.80      697752438
# 2  03-04-2020  8446.30  8819.40  8360.95  8792.20      815245226
# 3  07-04-2020  8688.90  9131.70  8653.90  8748.75      897562690
# 4  08-04-2020  8973.05  9128.35  8904.55  9111.90      743036134
#
#    Turnover in Cr  ohlc_average
# 0        21307.30     8406.0875
# 1        26561.18     8213.1750
# 2        35206.69     8604.7125
# 3        37641.68     8805.8125
# 4        32907.82     9029.4625

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Shares Traded  \
# 0  01-04-2020  8584.10  8588.10  8198.35  8253.80      507509685
# 1  02-04-2020  8356.55  8356.55  8055.80  8083.80      697752438
# 2  03-04-2020  8446.30  8819.40  8360.95  8792.20      815245226
# 3  07-04-2020  8688.90  9131.70  8653.90  8748.75      897562690
# 4  08-04-2020  8973.05  9128.35  8904.55  9111.90      743036134
#
#    Turnover in Cr  ohlc_average
# 0        21307.30     8406.0875
# 1        26561.18     8213.1750
# 2        35206.69     8604.7125
# 3        37641.68     8805.8125
# 4        32907.82     9029.4625

# %%
df.tail()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 73  21-07-2020  11126.10  11179.55  11113.25  11162.25      771998838
# 74  22-07-2020  11231.20  11238.10  11056.55  11132.60      765074288
# 75  23-07-2020  11135.00  11239.80  11103.15  11215.45      621575333
# 76  24-07-2020  11149.95  11225.40  11090.30  11194.15      678935175
# 77  27-07-2020  11225.00  11225.00  11087.85  11131.80      588148687
#
#     Turnover in Cr  ohlc_average
# 73        42461.89    11145.2875
# 74        41068.72    11164.6125
# 75        32744.93    11173.3500
# 76        40217.17    11164.9500
# 77        34539.73    11167.4125

# %% [markdown]
# # Predicting th Price of the Stock

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import accuracy_score

# %%
prices = df['Close'].tolist()
initial = (df['Open']).tolist()
 
#Convert to 1d Vector
prices = np.reshape(prices, (len(prices), 1))
initial = np.reshape(initial, (len(initial), 1))

# %%
xtrain, xtest, ytrain, ytest = train_test_split(prices,initial, test_size=0.33, random_state=42)
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print('Train-set /','R2 score:',r2_score(ytrain,regressor.predict(xtrain)))
plt.scatter(xtrain, ytrain, color='red', label= 'Actual Price') #plotting the initial datapoints
plt.plot(xtrain, regressor.predict(xtrain), color='blue', linewidth=3, label = 'Predicted Price') #plotting the line made by linear regression
plt.title('Linear Regression price| Open vs. Close')
plt.legend()
plt.xlabel('Prices')
plt.show()
# Out:
# Train-set / R2 score: 0.9648947541818861

# %%
print('Test-set/','R2 score:',r2_score(ytest,regressor.predict(xtest)))
plt.scatter(xtest, ytest, color='red', label= 'Actual Price') #plotting the initial datapoints
plt.plot(xtest, regressor.predict(xtest), color='blue', linewidth=3, label = 'Predicted Price') #plotting the line made by linear regression
plt.title('Linear Regression price| Open vs. Close')
plt.legend()
plt.xlabel('Prices')
plt.show()
# Out:
# Test-set/ R2 score: 0.9681664971323427

# %%
prices1 = df['High'].tolist()
initial1 = (df['Low']).tolist()
 
#Convert to 1d Vector
Prices = np.reshape(prices1, (len(prices1), 1))
Initial = np.reshape(initial1, (len(initial1), 1))

# %%
xtrain, xtest, ytrain, ytest = train_test_split(prices,initial, test_size=0.33, random_state=42)
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print('Train-set /','R2 score:',r2_score(ytrain,regressor.predict(xtrain)))
plt.scatter(xtrain, ytrain, color='red', label= 'Actual Price') #plotting the initial datapoints
plt.plot(xtrain, regressor.predict(xtrain), color='blue', linewidth=3, label = 'Predicted Price') #plotting the line made by linear regression
plt.title('Linear Regression price| High vs. Low')
plt.legend()
plt.xlabel('Prices')
plt.show()
# Out:
# Train-set / R2 score: 0.9648947541818861

# %%
print('Test-set/','R2 score:',r2_score(ytest,regressor.predict(xtest)))
plt.scatter(xtest, ytest, color='red', label= 'Actual Price') #plotting the initial datapoints
plt.plot(xtest, regressor.predict(xtest), color='blue', linewidth=3, label = 'Predicted Price') #plotting the line made by linear regression
plt.title('Linear Regression price| High vs. Close')
plt.legend()
plt.xlabel('Prices')
plt.show()
# Out:
# Test-set/ R2 score: 0.9681664971323427

# %% [markdown]
# In this example I tried  to use information of a National Stock Exchange Data and it is pretty stable in the stock prices so the simple correlation is going to get a good performance, but with other Stock data that could have more random behavior the simple linear regression may have issues. Though, in this case I could  have use other types of regression models for example the polinomial regresion that is not that is not as powerful as more complex models, but have less computacional cost and could get good enough results.
